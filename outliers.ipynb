# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
##box plot
import numpy as np

lst_marks = [45, 32, 56, 75, 89, 54, 32, 89, 90, 77, 43, 89,11, 82, 93]
minimum, q1, median, q3, maximum = np.quantile(lst_marks,[0,0.25, 0.5, 0.75, 1.0])
# Out:
# 11.0

# %%
minimum
# Out:
# 11.0

# %%
maximum
# Out:
# 93.0

# %%
median
# Out:
# 75.0

# %%
q1
# Out:
# 44.0

# %%
q3
# Out:
# 89.0

# %%
import seaborn as sns

lst_marks = [45, 32, 56, 75, 89, 54, 32, 89, 90, 77, 43, 89,11, 82, 93]


sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks = [45, 32, 56, 75, 89, 54, 32, 89, 90, 77, 43, 89,11, 82, 93, 150, 200, 390]
sns.boxplot(lst_marks)
# Out:
# <Axes: >
